# %%
# import pandas, matplotlib
import pandas as pd

# %%
# read in the csv from https://raw.githubusercontent.com/fivethirtyeight/data/master/flying-etiquette-survey/flying-etiquette.csv
fte = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/flying-etiquette-survey/flying-etiquette.csv')

# %%
# view the head
fte.head()
# Out:
#    RespondentID How often do you travel by plane?  \
# 0    3436139758               Once a year or less
# 1    3434278696               Once a year or less
# 2    3434275578               Once a year or less
# 3    3434268208               Once a year or less
# 4    3434250245              Once a month or less
#
#   Do you ever recline your seat when you fly? How tall are you?  \
# 0                                         NaN               NaN
# 1                         About half the time              6'3"
# 2                                     Usually              5'8"
# 3                                      Always             5'11"
# 4                         About half the time              5'7"
#
#   Do you have any children under 18?  \
# 0                                NaN
# 1                                Yes
# 2                                 No
# 3                                 No
# 4                                 No
#
#   In a row of three seats, who should get to use the two arm rests?  \
# 0                                                NaN
# 1                     The arm rests should be shared
# 2       Whoever puts their arm on the arm rest first
# 3                     The arm rests should be shared
# 4  The person in the middle seat gets both arm rests
#
#   In a row of two seats, who should get to use the middle arm rest?  \
# 0                                                NaN
# 1                     The arm rests should be shared
# 2                     The arm rests should be shared
# 3                     The arm rests should be shared
# 4                                The person in aisle
#
#       Who should have control over the window shade?  \
# 0                                                NaN
# 1           Everyone in the row should have some say
# 2  The person in the window seat should have excl...
# 3           Everyone in the row should have some say
# 4           Everyone in the row should have some say
#
#   Is itrude to move to an unsold seat on a plane?  \
# 0                                             NaN
# 1                             No, not rude at all
# 2                             No, not rude at all
# 3                             No, not rude at all
# 4                             No, not rude at all
#
#   Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?  \
# 0                                                NaN
# 1                                No, not at all rude
# 2                                No, not at all rude
# 3                                No, not at all rude
# 4                                No, not at all rude
#
#             ...             \
# 0           ...
# 1           ...
# 2           ...
# 3           ...
# 4           ...
#
#   Is itrude to wake a passenger up if you are trying to walk around?  \
# 0                                                NaN
# 1                                No, not at all rude
# 2                                 Yes, somewhat rude
# 3                                 Yes, somewhat rude
# 4                                 Yes, somewhat rude
#
#   In general, is itrude to bring a baby on a plane?  \
# 0                                               NaN
# 1                               No, not at all rude
# 2                                Yes, somewhat rude
# 3                                Yes, somewhat rude
# 4                                Yes, somewhat rude
#
#   In general, is it rude to knowingly bring unruly children on a plane?  \
# 0                                                NaN
# 1                                No, not at all rude
# 2                                     Yes, very rude
# 3                                     Yes, very rude
# 4                                     Yes, very rude
#
#   Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?  \
# 0                                                NaN
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                Yes
#
#   Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?  \
# 0                                                NaN
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Gender    Age     Household Income        Education Location (Census Region)
# 0    NaN    NaN                  NaN              NaN                      NaN
# 1   Male  30-44                  NaN  Graduate degree                  Pacific
# 2   Male  30-44  $100,000 - $149,999  Bachelor degree                  Pacific
# 3   Male  30-44         $0 - $24,999  Bachelor degree                  Pacific
# 4   Male  30-44    $50,000 - $99,999  Bachelor degree                  Pacific
#
# [5 rows x 27 columns]

# %%
# view the columns - use iteration to print them out
columns = []
for col in fte.columns:
    columns.append(col)
    
columns
# Out:
# ['RespondentID',
#  'How often do you travel by plane?',
#  'Do you ever recline your seat when you fly?',
#  'How tall are you?',
#  'Do you have any children under 18?',
#  'In a row of three seats, who should get to use the two arm rests?',
#  'In a row of two seats, who should get to use the middle arm rest?',
#  'Who should have control over the window shade?',
#  'Is itrude to move to an unsold seat on a plane?',
#  'Generally speaking, is it rude to say more than a few words tothe stranger sitting next to you on a plane?',
#  "On a 6 hour flight from NYC to LA, how many times is it acceptable to get up if you're not in an aisle seat?",
#  'Under normal circumstances, does a person who reclines their seat during a flight have any obligation to the person sitting behind them?',
#  'Is itrude to recline your seat on a plane?',
#  'Given the opportunity, would you eliminate the possibility of reclining seats on planes entirely?',
#  'Is it rude to ask someone to switch seats with you in order to be closer to friends?',
#  'Is itrude to ask someone to switch seats with you in order to be closer to family?',
#  'Is it rude to wake a passenger up if you are trying to go to the bathroom?',
#  'Is itrude to wake a passenger up if you are trying to walk around?',
#  'In general, is itrude to bring a baby on a plane?',
#  'In general, is it rude to knowingly bring unruly children on a plane?',
#  "Have you ever used personal electronics during take off or landing in violation of a flight attendant's direction?",
#  'Have you ever smoked a cigarette in an airplane bathroom when it was against the rules?',
#  'Gender',
#  'Age',
#  'Household Income',
#  'Education',
#  'Location (Census Region)']

# %%
# rename columns with shorter name
fte.columns = ['RespondentID', 'Travel by plane','Recline your seat','Height','Children under 18',\
                      'User of two arm rests','User of middle arm rest','Control over the window shade',\
                      'Move to an unsold','Say words to neighbor','Get up if not in aisle seat',\
                      'Reclines seat; rude sitting behind','Rude to recline seat','Eliminate reclining seats',\
                      'Ask to switch seats - friends','Ask to switch seats - family','Wake a passenger for bathroom',\
                      'Wake a passenger to walk','Rude to bring a baby','Rude to bring unruly children',\
                      "Used personal electronics during take off or landing",'Smoked a cigarette in bathroom',\
                      'Gender','Age','Household Income','Education','Location (Census Region)']
fte
# Out:
#       RespondentID        Travel by plane    Recline your seat Height  \
# 0       3436139758    Once a year or less                  NaN    NaN
# 1       3434278696    Once a year or less  About half the time   6'3"
# 2       3434275578    Once a year or less              Usually   5'8"
# 3       3434268208    Once a year or less               Always  5'11"
# 4       3434250245   Once a month or less  About half the time   5'7"
# 5       3434245875    Once a year or less              Usually   5'9"
# 6       3434235351   Once a month or less      Once in a while   6'2"
# 7       3434218031    Once a year or less      Once in a while   6'0"
# 8       3434213681    Once a year or less      Once in a while   6'0"
# 9       3434172894    Once a year or less                Never   5'6"
# 10      3434165659   Once a month or less              Usually   6'0"
# 11      3434164339    Once a year or less                  NaN    NaN
# 12      3434161941    Once a year or less                Never   5'7"
# 13      3434155493                  Never                  NaN    NaN
# 14      3434132453                  Never                  NaN    NaN
# 15      3434131535    Once a year or less      Once in a while   6'0"
# 16      3434125180   A few times per week                  NaN    NaN
# 17      3434122066    Once a year or less               Always   5'8"
# 18      3434114105    Once a year or less      Once in a while   6'1"
# 19      3434109246    Once a year or less                  NaN    NaN
# 20      3434107997    Once a year or less                Never  5'10"
# 21      3434100967    Once a year or less      Once in a while   5'7"
# 22      3434087928                  Never                  NaN    NaN
# 23      3434084098                  Never                  NaN    NaN
# 24      3434071488                  Never                  NaN    NaN
# 25      3434061256                  Never                  NaN    NaN
# 26      3434059758                  Never                  NaN    NaN
# 27      3434052290    Once a year or less      Once in a while   6'0"
# 28      3434049700    Once a year or less  About half the time   6'2"
# 29      3434041278    Once a year or less               Always   5'6"
# ...            ...                    ...                  ...    ...
# 1010    3431751287    Once a year or less               Always   5'1"
# 1011    3431751153   Once a month or less      Once in a while   5'2"
# 1012    3431751080   Once a month or less              Usually   6'5"
# 1013    3431748816    Once a year or less               Always   5'2"
# 1014    3431748763    Once a year or less      Once in a while   5'5"
# 1015    3431748698  A few times per month                Never  5'10"
# 1016    3431747718    Once a year or less               Always   5'2"
# 1017    3431746726    Once a year or less      Once in a while   5'4"
# 1018    3431745079                  Never                  NaN    NaN
# 1019    3431744747   Once a month or less      Once in a while   5'8"
# 1020    3431744533  A few times per month      Once in a while   5'4"
# 1021    3431744015                  Never                  NaN    NaN
# 1022    3431743115   Once a month or less  About half the time   6'0"
# 1023    3431741243    Once a year or less                Never  5'10"
# 1024    3431740654    Once a year or less      Once in a while   5'6"
# 1025    3431738966  A few times per month               Always   5'4"
# 1026    3431737634    Once a year or less      Once in a while   5'6"
# 1027    3431737213    Once a year or less              Usually   5'8"
# 1028    3431737008    Once a year or less                Never   5'4"
# 1029    3431736876   Once a month or less      Once in a while   5'4"
# 1030    3431736855                  Never                  NaN    NaN
# 1031    3431736438                  Never                  NaN    NaN
# 1032    3431735911    Once a year or less               Always   5'3"
# 1033    3431734973                  Never                  NaN    NaN
# 1034    3431734398  A few times per month      Once in a while   6'1"
# 1035    3431732652    Once a year or less      Once in a while   5'7"
# 1036    3431731770                  Never                  NaN    NaN
# 1037    3431731485                  Never                  NaN    NaN
# 1038    3431731196                  Never                  NaN    NaN
# 1039    3431729581    Once a year or less      Once in a while   6'3"
#
#      Children under 18                              User of two arm rests  \
# 0                  NaN                                                NaN
# 1                  Yes                     The arm rests should be shared
# 2                   No       Whoever puts their arm on the arm rest first
# 3                   No                     The arm rests should be shared
# 4                   No  The person in the middle seat gets both arm rests
# 5                  Yes       Whoever puts their arm on the arm rest first
# 6                  Yes  The person in the middle seat gets both arm rests
# 7                  Yes                     The arm rests should be shared
# 8                  Yes                     The arm rests should be shared
# 9                   No                             Other (please specify)
# 10                  No                     The arm rests should be shared
# 11                 NaN                                                NaN
# 12                 NaN                     The arm rests should be shared
# 13                 NaN                                                NaN
# 14                 NaN                                                NaN
# 15                  No                     The arm rests should be shared
# 16                 NaN                                                NaN
# 17                 Yes                     The arm rests should be shared
# 18                  No                     The arm rests should be shared
# 19                 NaN                                                NaN
# 20                  No                     The arm rests should be shared
# 21                  No                     The arm rests should be shared
# 22                 NaN                                                NaN
# 23                 NaN                                                NaN
# 24                 NaN                                                NaN
# 25                 NaN                                                NaN
# 26                 NaN                                                NaN
# 27                  No                     The arm rests should be shared
# 28                  No                     The arm rests should be shared
# 29                  No                             Other (please specify)
# ...                ...                                                ...
# 1010                No       Whoever puts their arm on the arm rest first
# 1011                No                     The arm rests should be shared
# 1012                No                     The arm rests should be shared
# 1013                No  The person in the middle seat gets both arm rests
# 1014                No                     The arm rests should be shared
# 1015               Yes                     The arm rests should be shared
# 1016                No                     The arm rests should be shared
# 1017                No                     The arm rests should be shared
# 1018               NaN                                                NaN
# 1019                No                     The arm rests should be shared
# 1020               Yes                     The arm rests should be shared
# 1021               NaN                                                NaN
# 1022                No                     The arm rests should be shared
# 1023                No                     The arm rests should be shared
# 1024                No  The person in the middle seat gets both arm rests
# 1025                No                     The arm rests should be shared
# 1026                No                     The arm rests should be shared
# 1027                No       Whoever puts their arm on the arm rest first
# 1028                No                     The arm rests should be shared
# 1029                No  The people in the aisle and window seats get b...
# 1030               NaN                                                NaN
# 1031               NaN                                                NaN
# 1032                No       Whoever puts their arm on the arm rest first
# 1033               NaN                                                NaN
# 1034               Yes  The person in the middle seat gets both arm rests
# 1035                No                             Other (please specify)
# 1036               NaN                                                NaN
# 1037               NaN                                                NaN
# 1038               NaN                                                NaN
# 1039                No                     The arm rests should be shared
#
#                            User of middle arm rest  \
# 0                                              NaN
# 1                   The arm rests should be shared
# 2                   The arm rests should be shared
# 3                   The arm rests should be shared
# 4                              The person in aisle
# 5     Whoever puts their arm on the arm rest first
# 6     Whoever puts their arm on the arm rest first
# 7                   The arm rests should be shared
# 8                   The arm rests should be shared
# 9                           Other (please specify)
# 10                  The arm rests should be shared
# 11                                             NaN
# 12                  The arm rests should be shared
# 13                                             NaN
# 14                                             NaN
# 15                  The arm rests should be shared
# 16                                             NaN
# 17                  The arm rests should be shared
# 18                  The arm rests should be shared
# 19                                             NaN
# 20                  The arm rests should be shared
# 21                  The arm rests should be shared
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27    Whoever puts their arm on the arm rest first
# 28                  The arm rests should be shared
# 29                          Other (please specify)
# ...                                            ...
# 1010  Whoever puts their arm on the arm rest first
# 1011                The arm rests should be shared
# 1012                The arm rests should be shared
# 1013                      The person by the window
# 1014                The arm rests should be shared
# 1015                The arm rests should be shared
# 1016                           The person in aisle
# 1017                The arm rests should be shared
# 1018                                           NaN
# 1019                The arm rests should be shared
# 1020                The arm rests should be shared
# 1021                                           NaN
# 1022                The arm rests should be shared
# 1023                The arm rests should be shared
# 1024                The arm rests should be shared
# 1025                The arm rests should be shared
# 1026                The arm rests should be shared
# 1027  Whoever puts their arm on the arm rest first
# 1028                The arm rests should be shared
# 1029                      The person by the window
# 1030                                           NaN
# 1031                                           NaN
# 1032  Whoever puts their arm on the arm rest first
# 1033                                           NaN
# 1034                        Other (please specify)
# 1035                        Other (please specify)
# 1036                                           NaN
# 1037                                           NaN
# 1038                                           NaN
# 1039                The arm rests should be shared
#
#                           Control over the window shade    Move to an unsold  \
#      Smoked a cigarette in bathroom  Gender    Age     Household Income  \
# 0                               NaN     NaN    NaN                  NaN
# 1                                No    Male  30-44                  NaN
# 2                                No    Male  30-44  $100,000 - $149,999
# 3                                No    Male  30-44         $0 - $24,999
# 4                                No    Male  30-44    $50,000 - $99,999
# 5                                No    Male  30-44    $25,000 - $49,999
# 6                                No    Male  30-44               150000
# 7                                No    Male  30-44         $0 - $24,999
# 8                               NaN     NaN    NaN                  NaN
# 9                                No    Male  30-44         $0 - $24,999
# 10                               No    Male  30-44    $50,000 - $99,999
# 11                              NaN     NaN    NaN                  NaN
# 12                              NaN     NaN    NaN                  NaN
# 13                              NaN    Male  30-44  $100,000 - $149,999
# 14                              NaN    Male  18-29                  NaN
# 15                               No    Male  18-29               150000
# 16                              NaN     NaN    NaN                  NaN
# 17                               No    Male  30-44  $100,000 - $149,999
# 18                               No    Male  30-44               150000
# 19                              NaN     NaN    NaN                  NaN
# 20                               No    Male  18-29    $25,000 - $49,999
# 21                               No    Male  30-44         $0 - $24,999
# 22                              NaN    Male  18-29    $50,000 - $99,999
# 23                              NaN    Male  18-29         $0 - $24,999
# 24                              NaN    Male  18-29    $50,000 - $99,999
# 25                              NaN    Male  30-44                  NaN
# 26                              NaN    Male  18-29    $50,000 - $99,999
# 27                               No    Male  30-44    $25,000 - $49,999
# 28                               No    Male  18-29    $50,000 - $99,999
# 29                               No    Male  30-44               150000
# ...                             ...     ...    ...                  ...
# 1010                             No  Female  45-60         $0 - $24,999
# 1011                             No  Female  18-29         $0 - $24,999
# 1012                             No    Male  18-29    $25,000 - $49,999
# 1013                             No  Female  45-60                  NaN
# 1014                             No  Female   > 60    $25,000 - $49,999
# 1015                             No    Male  45-60               150000
# 1016                             No  Female  18-29    $25,000 - $49,999
# 1017                             No  Female  45-60    $50,000 - $99,999
# 1018                            NaN  Female   > 60                  NaN
# 1019                             No    Male   > 60               150000
# 1020                             No  Female  30-44                  NaN
# 1021                            NaN  Female   > 60                  NaN
# 1022                             No    Male  45-60  $100,000 - $149,999
# 1023                             No  Female  18-29         $0 - $24,999
# 1024                             No  Female   > 60    $50,000 - $99,999
# 1025                             No  Female  45-60               150000
# 1026                             No  Female  18-29                  NaN
# 1027                             No    Male  45-60               150000
# 1028                             No  Female   > 60    $50,000 - $99,999
# 1029                             No  Female  18-29                  NaN
# 1030                            NaN  Female  30-44         $0 - $24,999
# 1031                            NaN  Female  30-44    $25,000 - $49,999
# 1032                             No  Female  30-44               150000
# 1033                            NaN  Female  18-29         $0 - $24,999
# 1034                             No    Male  30-44               150000
# 1035                             No    Male  30-44         $0 - $24,999
# 1036                            NaN    Male  45-60               150000
# 1037                            NaN  Female   > 60                  NaN
# 1038                            NaN  Female  30-44    $50,000 - $99,999
# 1039                             No    Male   > 60    $50,000 - $99,999
#
#                              Education Location (Census Region)
# 0                                  NaN                      NaN
# 1                      Graduate degree                  Pacific
# 2                      Bachelor degree                  Pacific
# 3                      Bachelor degree                  Pacific
# 4                      Bachelor degree                  Pacific
# 5                      Graduate degree       East North Central
# 6     Some college or Associate degree                  Pacific
# 7                      Bachelor degree              New England
# 8                                  NaN                      NaN
# 9                      Bachelor degree                  Pacific
# 10                  High school degree                 Mountain
# 11                                 NaN                      NaN
# 12                                 NaN                      NaN
# 13    Some college or Associate degree                  Pacific
# 14                  High school degree           South Atlantic
# 15    Some college or Associate degree       East South Central
# 16                                 NaN                      NaN
# 17    Some college or Associate degree          Middle Atlantic
# 18                     Bachelor degree       West North Central
# 19                                 NaN                      NaN
# 20                     Bachelor degree           South Atlantic
# 21                     Bachelor degree       East North Central
# 22                     Bachelor degree       East North Central
# 23    Some college or Associate degree       East North Central
# 24                     Bachelor degree                  Pacific
# 25                  High school degree          Middle Atlantic
# 26                     Bachelor degree                  Pacific
# 27                     Bachelor degree       East North Central
# 28    Some college or Associate degree       West South Central
# 29    Some college or Associate degree                  Pacific
# ...                                ...                      ...
# 1010                   Graduate degree                  Pacific
# 1011                   Graduate degree                  Pacific
# 1012  Some college or Associate degree       East North Central
# 1013  Some college or Associate degree          Middle Atlantic
# 1014  Some college or Associate degree                  Pacific
# 1015                   Graduate degree                 Mountain
# 1016  Some college or Associate degree                 Mountain
# 1017                   Bachelor degree                  Pacific
# 1018                   Bachelor degree          Middle Atlantic
# 1019                   Graduate degree                  Pacific
# 1020                   Graduate degree                  Pacific
# 1021  Some college or Associate degree       West South Central
# 1022                   Bachelor degree       West North Central
# 1023  Some college or Associate degree                  Pacific
# 1024                   Bachelor degree       West North Central
# 1025  Some college or Associate degree                  Pacific
# 1026  Some college or Associate degree       West South Central
# 1027                   Graduate degree                  Pacific
# 1028                   Graduate degree       West North Central
# 1029                   Bachelor degree       East North Central
# 1030                   Bachelor degree                  Pacific
# 1031  Some college or Associate degree       East South Central
# 1032                High school degree          Middle Atlantic
# 1033  Some college or Associate degree       West South Central
# 1034                   Graduate degree                  Pacific
# 1035  Some college or Associate degree       East North Central
# 1036                   Bachelor degree                  Pacific
# 1037  Some college or Associate degree       East North Central
# 1038                   Bachelor degree              New England
# 1039                   Bachelor degree                  Pacific
#
# [1040 rows x 27 columns]

# %%
# view head again - now just 3 rows
fte.head(3)
# Out:
#    RespondentID      Travel by plane    Recline your seat Height  \
# 0    3436139758  Once a year or less                  NaN    NaN
# 1    3434278696  Once a year or less  About half the time   6'3"
# 2    3434275578  Once a year or less              Usually   5'8"
#
#   Children under 18                         User of two arm rests  \
# 0               NaN                                           NaN
# 1               Yes                The arm rests should be shared
# 2                No  Whoever puts their arm on the arm rest first
#
#           User of middle arm rest  \
# 0                             NaN
# 1  The arm rests should be shared
# 2  The arm rests should be shared
#
#                        Control over the window shade    Move to an unsold  \
# 0                                                NaN                  NaN
# 1           Everyone in the row should have some say  No, not rude at all
# 2  The person in the window seat should have excl...  No, not rude at all
#
#   Say words to neighbor           ...            Wake a passenger to walk  \
# 0                   NaN           ...                                 NaN
# 1   No, not at all rude           ...                 No, not at all rude
# 2   No, not at all rude           ...                  Yes, somewhat rude
#
#   Rude to bring a baby Rude to bring unruly children  \
# 0                  NaN                           NaN
# 1  No, not at all rude           No, not at all rude
# 2   Yes, somewhat rude                Yes, very rude
#
#   Used personal electronics during take off or landing  \
# 0                                                NaN
# 1                                                 No
# 2                                                 No
#
#   Smoked a cigarette in bathroom Gender    Age     Household Income  \
# 0                            NaN    NaN    NaN                  NaN
# 1                             No   Male  30-44                  NaN
# 2                             No   Male  30-44  $100,000 - $149,999
#
#          Education Location (Census Region)
# 0              NaN                      NaN
# 1  Graduate degree                  Pacific
# 2  Bachelor degree                  Pacific
#
# [3 rows x 27 columns]

# %%
# view the last 3 rows
fte.tail(3)
# Out:
#       RespondentID      Travel by plane Recline your seat Height  \
# 1037    3431731485                Never               NaN    NaN
# 1038    3431731196                Never               NaN    NaN
# 1039    3431729581  Once a year or less   Once in a while   6'3"
#
#      Children under 18           User of two arm rests  \
# 1037               NaN                             NaN
# 1038               NaN                             NaN
# 1039                No  The arm rests should be shared
#
#              User of middle arm rest  \
# 1037                             NaN
# 1038                             NaN
# 1039  The arm rests should be shared
#
#                  Control over the window shade    Move to an unsold  \
# 1037                                       NaN                  NaN
# 1038                                       NaN                  NaN
# 1039  Everyone in the row should have some say  No, not rude at all
#
#      Say words to neighbor           ...            Wake a passenger to walk  \
# 1037                   NaN           ...                                 NaN
# 1038                   NaN           ...                                 NaN
# 1039   No, not at all rude           ...                  Yes, somewhat rude
#
#      Rude to bring a baby Rude to bring unruly children  \
# 1037                  NaN                           NaN
# 1038                  NaN                           NaN
# 1039   Yes, somewhat rude                Yes, very rude
#
#      Used personal electronics during take off or landing  \
# 1037                                                NaN
# 1038                                                NaN
# 1039                                                 No
#
#      Smoked a cigarette in bathroom  Gender    Age   Household Income  \
# 1037                            NaN  Female   > 60                NaN
# 1038                            NaN  Female  30-44  $50,000 - $99,999
# 1039                             No    Male   > 60  $50,000 - $99,999
#
#                              Education Location (Census Region)
# 1037  Some college or Associate degree       East North Central
# 1038                   Bachelor degree              New England
# 1039                   Bachelor degree                  Pacific
#
# [3 rows x 27 columns]

# %%
# check the data type of the DataFrame
type(fte)
# Out:
# pandas.core.frame.DataFrame

# %%
# How many unique travel frequencies are there? What are they?
fte['Travel by plane'].nunique()
# Out:
# 6

# %%
# How many unique regions are there? What are they?
fte['Location (Census Region)'].nunique()
# Out:
# 9

# %%
# Select just those columns that relate to the personal characteristics of the person
# Save that as a DataFrame name char

# %%
columns = ['Gender', 'Age', 'Household Income', 'Education', 'Location (Census Region)', 'Height']
fte[columns]
# Out:
#       Gender    Age     Household Income                         Education  \
# 0        NaN    NaN                  NaN                               NaN
# 1       Male  30-44                  NaN                   Graduate degree
# 2       Male  30-44  $100,000 - $149,999                   Bachelor degree
# 3       Male  30-44         $0 - $24,999                   Bachelor degree
# 4       Male  30-44    $50,000 - $99,999                   Bachelor degree
# 5       Male  30-44    $25,000 - $49,999                   Graduate degree
# 6       Male  30-44               150000  Some college or Associate degree
# 7       Male  30-44         $0 - $24,999                   Bachelor degree
# 8        NaN    NaN                  NaN                               NaN
# 9       Male  30-44         $0 - $24,999                   Bachelor degree
# 10      Male  30-44    $50,000 - $99,999                High school degree
# 11       NaN    NaN                  NaN                               NaN
# 12       NaN    NaN                  NaN                               NaN
# 13      Male  30-44  $100,000 - $149,999  Some college or Associate degree
# 14      Male  18-29                  NaN                High school degree
# 15      Male  18-29               150000  Some college or Associate degree
# 16       NaN    NaN                  NaN                               NaN
# 17      Male  30-44  $100,000 - $149,999  Some college or Associate degree
# 18      Male  30-44               150000                   Bachelor degree
# 19       NaN    NaN                  NaN                               NaN
# 20      Male  18-29    $25,000 - $49,999                   Bachelor degree
# 21      Male  30-44         $0 - $24,999                   Bachelor degree
# 22      Male  18-29    $50,000 - $99,999                   Bachelor degree
# 23      Male  18-29         $0 - $24,999  Some college or Associate degree
# 24      Male  18-29    $50,000 - $99,999                   Bachelor degree
# 25      Male  30-44                  NaN                High school degree
# 26      Male  18-29    $50,000 - $99,999                   Bachelor degree
# 27      Male  30-44    $25,000 - $49,999                   Bachelor degree
# 28      Male  18-29    $50,000 - $99,999  Some college or Associate degree
# 29      Male  30-44               150000  Some college or Associate degree
# ...      ...    ...                  ...                               ...
# 1010  Female  45-60         $0 - $24,999                   Graduate degree
# 1011  Female  18-29         $0 - $24,999                   Graduate degree
# 1012    Male  18-29    $25,000 - $49,999  Some college or Associate degree
# 1013  Female  45-60                  NaN  Some college or Associate degree
# 1014  Female   > 60    $25,000 - $49,999  Some college or Associate degree
# 1015    Male  45-60               150000                   Graduate degree
# 1016  Female  18-29    $25,000 - $49,999  Some college or Associate degree
# 1017  Female  45-60    $50,000 - $99,999                   Bachelor degree
# 1018  Female   > 60                  NaN                   Bachelor degree
# 1019    Male   > 60               150000                   Graduate degree
# 1020  Female  30-44                  NaN                   Graduate degree
# 1021  Female   > 60                  NaN  Some college or Associate degree
# 1022    Male  45-60  $100,000 - $149,999                   Bachelor degree
# 1023  Female  18-29         $0 - $24,999  Some college or Associate degree
# 1024  Female   > 60    $50,000 - $99,999                   Bachelor degree
# 1025  Female  45-60               150000  Some college or Associate degree
# 1026  Female  18-29                  NaN  Some college or Associate degree
# 1027    Male  45-60               150000                   Graduate degree
# 1028  Female   > 60    $50,000 - $99,999                   Graduate degree
# 1029  Female  18-29                  NaN                   Bachelor degree
# 1030  Female  30-44         $0 - $24,999                   Bachelor degree
# 1031  Female  30-44    $25,000 - $49,999  Some college or Associate degree
# 1032  Female  30-44               150000                High school degree
# 1033  Female  18-29         $0 - $24,999  Some college or Associate degree
# 1034    Male  30-44               150000                   Graduate degree
# 1035    Male  30-44         $0 - $24,999  Some college or Associate degree
# 1036    Male  45-60               150000                   Bachelor degree
# 1037  Female   > 60                  NaN  Some college or Associate degree
# 1038  Female  30-44    $50,000 - $99,999                   Bachelor degree
# 1039    Male   > 60    $50,000 - $99,999                   Bachelor degree
#
#      Location (Census Region) Height
# 0                         NaN    NaN
# 1                     Pacific   6'3"
# 2                     Pacific   5'8"
# 3                     Pacific  5'11"
# 4                     Pacific   5'7"
# 5          East North Central   5'9"
# 6                     Pacific   6'2"
# 7                 New England   6'0"
# 8                         NaN   6'0"
# 9                     Pacific   5'6"
# 10                   Mountain   6'0"
# 11                        NaN    NaN
# 12                        NaN   5'7"
# 13                    Pacific    NaN
# 14             South Atlantic    NaN
# 15         East South Central   6'0"
# 16                        NaN    NaN
# 17            Middle Atlantic   5'8"
# 18         West North Central   6'1"
# 19                        NaN    NaN
# 20             South Atlantic  5'10"
# 21         East North Central   5'7"
# 22         East North Central    NaN
# 23         East North Central    NaN
# 24                    Pacific    NaN
# 25            Middle Atlantic    NaN
# 26                    Pacific    NaN
# 27         East North Central   6'0"
# 28         West South Central   6'2"
# 29                    Pacific   5'6"
# ...                       ...    ...
# 1010                  Pacific   5'1"
# 1011                  Pacific   5'2"
# 1012       East North Central   6'5"
# 1013          Middle Atlantic   5'2"
# 1014                  Pacific   5'5"
# 1015                 Mountain  5'10"
# 1016                 Mountain   5'2"
# 1017                  Pacific   5'4"
# 1018          Middle Atlantic    NaN
# 1019                  Pacific   5'8"
# 1020                  Pacific   5'4"
# 1021       West South Central    NaN
# 1022       West North Central   6'0"
# 1023                  Pacific  5'10"
# 1024       West North Central   5'6"
# 1025                  Pacific   5'4"
# 1026       West South Central   5'6"
# 1027                  Pacific   5'8"
# 1028       West North Central   5'4"
# 1029       East North Central   5'4"
# 1030                  Pacific    NaN
# 1031       East South Central    NaN
# 1032          Middle Atlantic   5'3"
# 1033       West South Central    NaN
# 1034                  Pacific   6'1"
# 1035       East North Central   5'7"
# 1036                  Pacific    NaN
# 1037       East North Central    NaN
# 1038              New England    NaN
# 1039                  Pacific   6'3"
#
# [1040 rows x 6 columns]

# %%
# From the new char DataFrame, select the height. Can you create a histogram?
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# fte['Height'].hist() --- We can't create a histogram because we're given an error. Drat!

# %%
# Create a histogram by creating a list comprehension + a function to turn the data into inches

def cleanup(x):
    if pd.isnull(x):
        return x
    elif 'Under' in x:
        return 78
    elif 'above' in x:
        return 60
    else:
        feet = int(x.split("'")[0]) * 12
        inches = int(x.split("'")[1].replace('"',''))
        return feet + inches

fte['Height'] = [cleanup(x) for x in fte['Height']]

fte['Height'].hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-eef46f6ba851> in <module>()
#      13         return feet + inches
#      14
# ---> 15 fte['Height'] = [cleanup(x) for x in fte['Height']]
#      16
#      17 fte['Height'].hist()
#
# <ipython-input-47-eef46f6ba851> in cleanup(x)
#       4     if pd.isnull(x):
#       5         return x
# ----> 6     elif 'Under' in x:
#       7         return 78
#       8     elif 'above' in x:
#
# TypeError: argument of type 'numpy.float64' is not iterable

# %%
# Slice the first 3 columns using .iloc notation, then use the double bracket notation
fte.iloc[:,:3]
# Out:
#       RespondentID        Travel by plane    Recline your seat
# 0       3436139758    Once a year or less                  NaN
# 1       3434278696    Once a year or less  About half the time
# 2       3434275578    Once a year or less              Usually
# 3       3434268208    Once a year or less               Always
# 4       3434250245   Once a month or less  About half the time
# 5       3434245875    Once a year or less              Usually
# 6       3434235351   Once a month or less      Once in a while
# 7       3434218031    Once a year or less      Once in a while
# 8       3434213681    Once a year or less      Once in a while
# 9       3434172894    Once a year or less                Never
# 10      3434165659   Once a month or less              Usually
# 11      3434164339    Once a year or less                  NaN
# 12      3434161941    Once a year or less                Never
# 13      3434155493                  Never                  NaN
# 14      3434132453                  Never                  NaN
# 15      3434131535    Once a year or less      Once in a while
# 16      3434125180   A few times per week                  NaN
# 17      3434122066    Once a year or less               Always
# 18      3434114105    Once a year or less      Once in a while
# 19      3434109246    Once a year or less                  NaN
# 20      3434107997    Once a year or less                Never
# 21      3434100967    Once a year or less      Once in a while
# 22      3434087928                  Never                  NaN
# 23      3434084098                  Never                  NaN
# 24      3434071488                  Never                  NaN
# 25      3434061256                  Never                  NaN
# 26      3434059758                  Never                  NaN
# 27      3434052290    Once a year or less      Once in a while
# 28      3434049700    Once a year or less  About half the time
# 29      3434041278    Once a year or less               Always
# ...            ...                    ...                  ...
# 1010    3431751287    Once a year or less               Always
# 1011    3431751153   Once a month or less      Once in a while
# 1012    3431751080   Once a month or less              Usually
# 1013    3431748816    Once a year or less               Always
# 1014    3431748763    Once a year or less      Once in a while
# 1015    3431748698  A few times per month                Never
# 1016    3431747718    Once a year or less               Always
# 1017    3431746726    Once a year or less      Once in a while
# 1018    3431745079                  Never                  NaN
# 1019    3431744747   Once a month or less      Once in a while
# 1020    3431744533  A few times per month      Once in a while
# 1021    3431744015                  Never                  NaN
# 1022    3431743115   Once a month or less  About half the time
# 1023    3431741243    Once a year or less                Never
# 1024    3431740654    Once a year or less      Once in a while
# 1025    3431738966  A few times per month               Always
# 1026    3431737634    Once a year or less      Once in a while
# 1027    3431737213    Once a year or less              Usually
# 1028    3431737008    Once a year or less                Never
# 1029    3431736876   Once a month or less      Once in a while
# 1030    3431736855                  Never                  NaN
# 1031    3431736438                  Never                  NaN
# 1032    3431735911    Once a year or less               Always
# 1033    3431734973                  Never                  NaN
# 1034    3431734398  A few times per month      Once in a while
# 1035    3431732652    Once a year or less      Once in a while
# 1036    3431731770                  Never                  NaN
# 1037    3431731485                  Never                  NaN
# 1038    3431731196                  Never                  NaN
# 1039    3431729581    Once a year or less      Once in a while
#
# [1040 rows x 3 columns]

# %%
## Create a dictionary using .unique and a dictionary comprehension
## Then use a list comprehension with a function to update the count the number of degrees
## How many degreee of each type are there?

# %%
education = {}
education = {key:0 for key in fte['Education'].unique()}

education
# Out:
# {nan: 0,
#  'Bachelor degree': 0,
#  'Graduate degree': 0,
#  'High school degree': 0,
#  'Less than high school degree': 0,
#  'Some college or Associate degree': 0}

# %%
def counter(x):
    education[x] = education[x] + 1

for x in fte['Education']:
    counter(x)

education
# Out:
# {nan: 39,
#  'Bachelor degree': 325,
#  'Graduate degree': 284,
#  'High school degree': 98,
#  'Less than high school degree': 8,
#  'Some college or Associate degree': 286}

# %%
# Now use the education column with the .value_counts() method to check your work. Are they the same?
fte['Education'].value_counts()
# Out:
# Bachelor degree                     325
# Some college or Associate degree    286
# Graduate degree                     284
# High school degree                   98
# Less than high school degree          8
# Name: Education, dtype: int64
